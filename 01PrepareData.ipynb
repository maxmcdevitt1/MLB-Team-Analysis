# %% [markdown]
# # 01: Collect raw data
#
# Download batting, pitching, cutoff standings, and final records. Save them as Parquet files. Edit SEASONS and CUTOFF_MONTHS at the top of the Python file to change the dates.

# %%
# %run 01PrepareData.py
# Out:
# Collected 2016-06-01
# Collected 2016-07-01
# Collected 2016-08-01
# Collected 2016-09-01
# Collected 2017-06-01
# Collected 2017-07-01
# Collected 2017-08-01
# Collected 2017-09-01
# Collected 2018-06-01
# Collected 2018-07-01
# Collected 2018-08-01
# Collected 2018-09-01
# Collected 2019-06-01
# Collected 2019-07-01
# Collected 2019-08-01
# Collected 2019-09-01
# Collected 2020-08-01
# Collected 2020-09-01
# Collected 2021-06-01
# Collected 2021-07-01
# Collected 2021-08-01
# Collected 2021-09-01
# Collected 2022-06-01
# Collected 2022-07-01
# Collected 2022-08-01
# Collected 2022-09-01
# Collected 2023-06-01
# Collected 2023-07-01
# Collected 2023-08-01
# Collected 2023-09-01
# Collected 2024-06-01
# Collected 2024-07-01
# Collected 2024-08-01
# Collected 2024-09-01
# Collected 2025-06-01
# Collected 2025-07-01
# Collected 2025-08-01
# Collected 2025-09-01

# %% [markdown]
# ## Read the saved Parquet file

# %%
import pandas as pd

data = pd.read_parquet("data/team_snapshots.parquet")
print(f"Rows: {len(data)}")
data
# Out:
# Rows: 1140
#    Season Cutoff_Date  Team_ID                Team   G  groundOuts_bat  \
# 0    2016  2016-06-01      111      Boston Red Sox  53             519
# 1    2016  2016-06-01      134  Pittsburgh Pirates  52             542
# 2    2016  2016-06-01      115    Colorado Rockies  52             541
# 3    2016  2016-06-01      118  Kansas City Royals  52             498
# 4    2016  2016-06-01      146       Miami Marlins  53             552
#
#    airOuts_bat  runs_bat  doubles_bat  triples_bat  ...  strikeoutWalkRatio  \
# 0          435       317          136           17  ...                2.50
# 1          385       260           99           12  ...                2.00
# 2          406       265          108           17  ...                2.45
# 3          452       216           93            8  ...                2.38
# 4          403       208           91           12  ...                2.02
#
# ...
