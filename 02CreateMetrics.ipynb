# %% [markdown]
# # 02: Create features
#
# Read the raw Parquet file from 01 and calculate features. The formulas are in the Python file. No data is downloaded here.

# %%
# %run 02CreateMetrics.py
# Out:
# Saved 1140 feature rows

# %% [markdown]
# ## Read the saved Parquet file

# %%
import pandas as pd

data = pd.read_parquet("data/model_metrics.parquet")
print(f"Rows: {len(data)}")
data
# Out:
# Rows: 1140
#       Season  Team_ID League    G                  Team Cutoff_Date   W   L  \
# 0       2016      108     AL   53    Los Angeles Angels  2016-06-01  24  29
# 1       2016      109     NL   55  Arizona Diamondbacks  2016-06-01  23  32
# 2       2016      110     AL   51     Baltimore Orioles  2016-06-01  29  22
# 3       2016      111     AL   53        Boston Red Sox  2016-06-01  32  21
# 4       2016      112     NL   51          Chicago Cubs  2016-06-01  36  15
# ...      ...      ...    ...  ...                   ...         ...  ..  ..
# 1135    2025      144     NL  138        Atlanta Braves  2025-09-01  62  76
# 1136    2025      145     AL  138     Chicago White Sox  2025-09-01  50  88
# 1137    2025      146     NL  138         Miami Marlins  2025-09-01  65  73
# 1138    2025      147     AL  137      New York Yankees  2025-09-01  76  61
# 1139    2025      158     NL  139     Milwaukee Brewers  2025-09-01  85  54
#
# ...
