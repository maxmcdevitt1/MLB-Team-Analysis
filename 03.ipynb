# %% [markdown]
# # 03: Build training data
#
# Read the features from 02 and the final records from 01. Add the remaining-season win percentage as the target.

# %%
# %run 03-BuildTrainingData.py
# Out:
# Saved 1140 training rows

# %% [markdown]
# ## Read the saved Parquet file

# %%
import pandas as pd

data = pd.read_parquet("data/training_data.parquet")
print(f"Rows: {len(data)}")
data
# Out:
# Rows: 1140
#    Season  Team_ID League   G                  Team Cutoff_Date   W   L  \
# 0    2016      108     AL  53    Los Angeles Angels  2016-06-01  24  29
# 1    2016      109     NL  55  Arizona Diamondbacks  2016-06-01  23  32
# 2    2016      110     AL  51     Baltimore Orioles  2016-06-01  29  22
# 3    2016      111     AL  53        Boston Red Sox  2016-06-01  32  21
# 4    2016      112     NL  51          Chicago Cubs  2016-06-01  36  15
#
#    off_xbsr_per_game  allowed_xbsr_per_game  ...  pitch_hr_rate  \
# 0           3.908692               4.552655  ...       0.033697
# 1           4.861796               5.184935  ...       0.028675
# 2           4.629418               4.482743  ...       0.028365
# 3           6.030139               4.325561  ...       0.025049
# 4           5.095196               2.957755  ...       0.021219
#
#    pitch_k_minus_bb_rate   bat_iso  pitch_iso  final_W  final_L  \
# 0               0.113479  0.130288   0.164914       74       88
# ...
